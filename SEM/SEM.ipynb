# %%
import semopy
import pandas as pd

# %%
# Read the prepared dataset of measured variables (Xs) after Random Forest Imputation of Null Values.
X_imputed = pd.read_csv('D:/Projects/IDEA-FRM/InputData/SEM_X_Imputed.csv')
X_imputed = X_imputed.drop('Unnamed: 0', axis=1)

# %%
#Normalise the measured variables.
from sklearn.preprocessing import StandardScaler
X_cat = X_imputed.iloc[:,74:]
X_con = X_imputed.iloc[:,:74]

standardized_data = StandardScaler().fit_transform(X_con)

X_con = pd.DataFrame(standardized_data,columns=X_con.columns)
X_std_imputed = pd.concat([X_con,X_cat],axis=1)

# %%
#SEM Model Specification
model_spec = """
# measurement model
Inundation =~ assam_dist_from_major_rivers_updated_3857 + sum + GCN250_ARCIII_average + strm_filled_slope_degrees + ndvi + srtm_filled_dem + gmted_drainage_density_without_1
demography =~ ind_ppp_UNadj + aged + young + sexratio + percaay + deprived + nophone + noSanitation + nodrinkingWater + totLivestock
infra_access =~ ndbi + proximity_hosptial_rd + proximity_embankment_rd + proximity_rail_rd + proximity_local_rd + proximity_arterial_rd

frims_response =~ response_inmatesinReliefCamps + Relief_cam + Relief_dis + Rice + Salt + Oil + Dal
Sum_Total =~ Sum_SDRF + Sum_relief + Sum_new + Sum_Erosion + Sum_Roads + Sum_repair + Sum_IM
Count_Total =~ Count_SDRF + Count_relief + Count_new + Count_Erosion + Count_Road + Count_repair + Count_IM
frims_damages =~ damage_POPULATION_AFFECTED + damage_humanliveslost + damage_animalsaffectedtotal + damage_animalsaffectedpoultry + damage_animalsaffectedbig + damage_animalsaffectedsmall + damage_animals_washed_total + damage_animals_washed_poultry + damage_animals_washed_big + damage_animals_washed_small + damage_Houses_damaged_fully + damage_Houses_damaged_partially + damage_croparea_AFFECTED + Embankment + Other + Road + Bridge
Preparedness =~ Sum_Total + Count_Total + frims_response + frims_damages

# regressions
Preparedness ~ Inundation + demography + infra_access

# residual correlations
frims_response ~~ frims_damages
Sum_Total ~~ frims_damages
Count_Total ~~ frims_damages
Count_Total ~~ Sum_Total
"""

# %%
# Model specification
model = semopy.Model(model_spec)

# %%
# Fit Model
model.fit(X_std_imputed.sample(1000))
# Out:
# SolverResult(fun=43.573331399459136, success=True, n_it=140, x=array([-4.93491654e-01, -1.33697576e+00,  3.82857692e-01,  1.20683759e+00,
#         1.81795358e+00, -1.82720886e+00,  8.16916043e-01,  9.97388707e-01,
#         1.88006491e-01,  1.03767804e+00,  7.91477247e-01,  1.24641527e+00,
#         9.17281166e-01,  5.57529959e-01,  1.12163903e+00, -3.11250802e+00,
#         5.38374998e-01, -1.81862129e+00, -2.02756157e+00, -2.39974189e+00,
#         1.49744007e+00,  1.17511423e+00,  6.54471927e+00,  4.83084704e+00,
#         5.71273699e-02,  6.41698050e+00,  1.76922245e-01,  6.10098725e-01,
#         3.53974576e-01,  7.31520543e-01,  9.46031160e-01,  1.30475105e+00,
#         1.90636523e-01,  2.50067660e-01,  2.68928888e-01,  6.34474323e-01,
#         8.58516631e-01,  1.01117538e+00, -2.23592243e-02,  2.06809138e+00,
#         1.97574379e+00,  1.89482252e+00,  1.97550500e+00,  4.37098635e-01,
#         5.99960694e-01,  1.02692253e-01,  1.08196701e-01,  2.36029893e-01,
#         3.38328479e-01,  3.93649075e-01,  5.53976311e-01, -2.13508595e-02,
#         1.07354290e+00,  8.12821005e-01,  1.05598411e+00,  3.39925929e-01,
#         1.46016576e+00, -2.72862175e-01,  2.20174132e-02, -8.91369710e-02,
#         6.30162809e-02,  2.35092523e-02,  3.86322072e-04,  3.68547575e-01,
#        -3.55992175e-03,  3.87060571e-01,  6.80581423e-01,  9.30596463e-01,
#         7.76144884e-01,  5.58712861e-01,  2.14236130e-01,  1.80563564e-16,
#         8.80290001e-01,  3.41219270e-01,  7.20522406e-01,  8.38625203e-01,
#         3.30732539e-07,  9.36452978e-01,  6.90136912e-01,  1.09599309e+00,
#         1.33852289e-01,  2.93187339e-01,  9.70089481e-01,  4.84578767e-01,
#         9.89257258e-01,  1.32924733e-02,  1.47420641e+00,  7.49049325e-01,
#         7.49596689e-01,  3.37280446e-03,  1.43912196e+00,  1.44002949e+00,
#         7.76991753e-01,  1.38021161e+00,  1.49303060e-01,  7.22609172e-16,
#         1.10276487e+00,  3.26638309e-01,  2.28307691e-01,  1.01898967e+00,
#         6.89464030e-01,  9.46615273e-01,  7.80415423e-01,  3.48817067e-01,
#         1.55376768e-01,  7.56874623e-01,  9.87719785e-01,  8.87544625e-01,
#         6.94355564e-01,  2.79428699e-01,  2.54471457e-01,  9.02312325e-01,
#         1.97954453e-16,  1.93981829e-01,  5.24840384e-01,  5.83914728e-01,
#         1.19301676e+00,  6.43081468e-01,  1.33783104e-01,  4.92770077e-01,
#         4.91328776e-01,  1.10880610e+00,  4.43386283e-01,  9.63939974e-02,
#         9.31256437e-01,  5.68152257e-01,  2.73215554e-02,  4.52525342e-01,
#         1.78162521e-01,  3.55308545e-01,  8.75286891e-01,  1.13149535e-01,
#        -1.55345448e-01,  9.18125087e-02, -7.81762454e-02,  1.82265269e-01]), message='Optimization terminated successfully', name_method='SLSQP', name_obj='MLW')

# %%
# Save co-efficient estimates in a dataframe
coeff_df = model.inspect()

# %%
coeff_df
# Out:
#                           lval  op                       rval       Estimate  \
# 0                    Sum_Total   ~               Preparedness            1.0
# 1                  Count_Total   ~               Preparedness  Not estimated
# 2               frims_response   ~               Preparedness  Not estimated
# 3                frims_damages   ~               Preparedness  Not estimated
# 4                 Preparedness   ~                 Inundation  Not estimated
# ..                         ...  ..                        ...            ...
# 139                  Count_new  ~~                  Count_new  Not estimated
# 140                   sexratio  ~~                   sexratio  Not estimated
# 141  damage_animals_washed_big  ~~  damage_animals_washed_big  Not estimated
# 142                 Count_SDRF  ~~                 Count_SDRF  Not estimated
# 143                      Other  ~~                      Other  Not estimated
#
#     Std. Err z-value p-value
# 0          -       -       -
# 1          -       -       -
# 2          -       -       -
# 3          -       -       -
# 4          -       -       -
# ..       ...     ...     ...
# 139        -       -       -
# 140        -       -       -
# 141        -       -       -
# 142        -       -       -
# 143        -       -       -
#
# [144 rows x 7 columns]
